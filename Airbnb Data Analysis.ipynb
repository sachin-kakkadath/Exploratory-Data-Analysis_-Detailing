# %%
from IPython.display import Image
Image(r"C:\Users\bmthm\Desktop\Screenshot 2023-03-24 153936.jpg")

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
#Data Ingesion
df =  pd.read_csv (r"C:\Users\bmthm\Downloads\airbnb prices.csv")

# %%
df.head()
# Out:
#     room_id  survey_id   host_id    room_type  country       city  borough  \
# 0  10176931       1476  49180562  Shared room      NaN  Amsterdam      NaN
# 1   8935871       1476  46718394  Shared room      NaN  Amsterdam      NaN
# 2  14011697       1476  10346595  Shared room      NaN  Amsterdam      NaN
# 3   6137978       1476   8685430  Shared room      NaN  Amsterdam      NaN
# 4  18630616       1476  70191803  Shared room      NaN  Amsterdam      NaN
#
#               neighborhood  reviews  overall_satisfaction  accommodates  \
# 0  De Pijp / Rivierenbuurt        7                   4.5             2
# 1             Centrum West       45                   4.5             4
# 2          Watergraafsmeer        1                   0.0             3
# 3             Centrum West        7                   5.0             4
# 4   De Baarsjes / Oud West        1                   0.0             2
#
#    bedrooms  bathrooms  price  minstay  \
# ...

# %%
df.shape
# Out:
# (18723, 20)

# %%
df.size
# Out:
# 374460

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18723 entries, 0 to 18722
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   room_id               18723 non-null  int64
#  1   survey_id             18723 non-null  int64
#  2   host_id               18723 non-null  int64
#  3   room_type             18723 non-null  object
#  4   country               0 non-null      float64
#  5   city                  18723 non-null  object
#  6   borough               0 non-null      float64
#  7   neighborhood          18723 non-null  object
#  8   reviews               18723 non-null  int64
#  9   overall_satisfaction  18723 non-null  float64
#  10  accommodates          18723 non-null  int64
#  11  bedrooms              18723 non-null  float64
#  12  bathrooms             0 non-null      float64
#  13  price                 18723 non-null  float64
#  14  minstay               0 non-null      float64
# ...

# %%
miss_val_df = df.isnull().sum()
miss_val_percent_df = 100 * df.isnull().sum() /len(df)
miss_val_table_df = pd.concat([miss_val_df,miss_val_percent_df],axis = 1)
miss_val_table_df = miss_val_table_df.rename(columns = {0 : 'Missing Values count', 1 : '% of Total Values'})
miss_val_table_df.sort_values("Missing Values count").round(2)
# Out:
#                       Missing Values count  % of Total Values
# room_id                                  0               0.00
# latitude                                 0               0.00
# last_modified                            0               0.00
# price                                    0               0.00
# bedrooms                                 0               0.00
# accommodates                             0               0.00
# longitude                                0               0.00
# reviews                                  0               0.00
# overall_satisfaction                     0               0.00
# city                                     0               0.00
# room_type                                0               0.00
# host_id                                  0               0.00
# survey_id                                0               0.00
# neighborhood                             0               0.00
# ...

# %%
df.bathrooms.unique()
# Out:
# array([nan])

# %%
df_new = df.copy()

# %%
df_new
# Out:
#         room_id  survey_id    host_id     room_type  country       city  \
# 0      10176931       1476   49180562   Shared room      NaN  Amsterdam
# 1       8935871       1476   46718394   Shared room      NaN  Amsterdam
# 2      14011697       1476   10346595   Shared room      NaN  Amsterdam
# 3       6137978       1476    8685430   Shared room      NaN  Amsterdam
# 4      18630616       1476   70191803   Shared room      NaN  Amsterdam
# ...         ...        ...        ...           ...      ...        ...
# 18718  17789893       1476   47501089  Private room      NaN  Amsterdam
# 18719  16877166       1476   67093870  Private room      NaN  Amsterdam
# 18720  19859427       1476   29724632  Private room      NaN  Amsterdam
# 18721  17132164       1476  115156569  Private room      NaN  Amsterdam
# 18722   7605782       1476   39503013  Private room      NaN  Amsterdam
#
#        borough             neighborhood  reviews  overall_satisfaction  \
# ...

# %%
#Dropping irrelevant columns

df_new = df_new.drop(['city','bathrooms','minstay','country','borough','room_id','survey_id','host_id','location','last_modified'],axis =1)

# %%
df_new.head()
# Out:
#      room_type             neighborhood  reviews  overall_satisfaction  \
# 0  Shared room  De Pijp / Rivierenbuurt        7                   4.5
# 1  Shared room             Centrum West       45                   4.5
# 2  Shared room          Watergraafsmeer        1                   0.0
# 3  Shared room             Centrum West        7                   5.0
# 4  Shared room   De Baarsjes / Oud West        1                   0.0
#
#    accommodates  bedrooms  price  \
# 0             2       1.0  156.0
# 1             4       1.0  126.0
# 2             3       1.0  132.0
# 3             4       1.0  121.0
# 4             2       1.0   93.0
#
#                                              name   latitude  longitude
# 0        Red Light/ Canal view apartment (Shared)  52.356209   4.887491
# 1  Sunny and Cozy Living room in quite neighbours  52.378518   4.896120
# 2                                       Amsterdam  52.338811   4.943592
# ...

# %% [markdown]
# **Missing value treatment**

# %%
miss_val_df = df_new.isnull().sum()
miss_val_percent_df = 100 * df_new.isnull().sum() /len(df)
miss_val_table_df = pd.concat([miss_val_df,miss_val_percent_df],axis = 1)
miss_val_table_df = miss_val_table_df.rename(columns = {0 : 'Missing Values count', 1 : '% of Total Values'})
miss_val_table_df.sort_values("Missing Values count").round(2)
# Out:
#                       Missing Values count  % of Total Values
# room_type                                0               0.00
# neighborhood                             0               0.00
# reviews                                  0               0.00
# overall_satisfaction                     0               0.00
# accommodates                             0               0.00
# bedrooms                                 0               0.00
# price                                    0               0.00
# latitude                                 0               0.00
# longitude                                0               0.00
# name                                    52               0.28

# %%
df_new.name.unique()
# Out:
# array(['Red Light/ Canal view apartment (Shared)',
#        'Sunny and Cozy Living room in quite neighbours', 'Amsterdam', ...,
#        'Private single room',
#        'City Center studio in Touristic Amsterdam 1',
#        'I have a room available for rent'], dtype=object)

# %%
df_new = df_new.dropna()

# %%
miss_val_df = df_new.isnull().sum()
miss_val_percent_df = 100 * df_new.isnull().sum() /len(df)
miss_val_table_df = pd.concat([miss_val_df,miss_val_percent_df],axis = 1)
miss_val_table_df = miss_val_table_df.rename(columns = {0 : 'Missing Values count', 1 : '% of Total Values'})
miss_val_table_df.sort_values("Missing Values count").round(2)
# Out:
#                       Missing Values count  % of Total Values
# room_type                                0                0.0
# neighborhood                             0                0.0
# reviews                                  0                0.0
# overall_satisfaction                     0                0.0
# accommodates                             0                0.0
# bedrooms                                 0                0.0
# price                                    0                0.0
# name                                     0                0.0
# latitude                                 0                0.0
# longitude                                0                0.0

# %%
df_new.size
# Out:
# 186710

# %%
df_new.shape
# Out:
# (18671, 10)

# %%
df.shape
# Out:
# (18723, 20)

# %%
df_new.neighborhood.unique()
# Out:
# array(['De Pijp / Rivierenbuurt', 'Centrum West', 'Watergraafsmeer',
#        'De Baarsjes / Oud West', 'Oostelijk Havengebied / Indische Buurt',
#        'Westerpark', 'Oud Oost', 'Centrum Oost',
#        'Geuzenveld / Slotermeer', 'Buitenveldert / Zuidas', 'Oud Noord',
#        'Bos en Lommer', 'Slotervaart', 'Bijlmer Centrum',
#        'Ijburg / Eiland Zeeburg', 'Noord-West / Noord-Midden',
#        'De Aker / Nieuw Sloten', 'Noord West', 'Bijlmer Oost', 'Osdorp',
#        'Noord Oost', 'Gaasperdam / Driemond', 'Westpoort'], dtype=object)

# %%
df_new.head()
# Out:
#      room_type             neighborhood  reviews  overall_satisfaction  \
# 0  Shared room  De Pijp / Rivierenbuurt        7                   4.5
# 1  Shared room             Centrum West       45                   4.5
# 2  Shared room          Watergraafsmeer        1                   0.0
# 3  Shared room             Centrum West        7                   5.0
# 4  Shared room   De Baarsjes / Oud West        1                   0.0
#
#    accommodates  bedrooms  price  \
# 0             2       1.0  156.0
# 1             4       1.0  126.0
# 2             3       1.0  132.0
# 3             4       1.0  121.0
# 4             2       1.0   93.0
#
#                                              name   latitude  longitude
# 0        Red Light/ Canal view apartment (Shared)  52.356209   4.887491
# 1  Sunny and Cozy Living room in quite neighbours  52.378518   4.896120
# 2                                       Amsterdam  52.338811   4.943592
# ...

# %%
cats = list(df_new.select_dtypes(include = ['object']).columns)
nums = list(df_new.select_dtypes(exclude = ['object']).columns)

# %%
cats
# Out:
# ['room_type', 'neighborhood', 'name']

# %%
nums
# Out:
# ['reviews',
#  'overall_satisfaction',
#  'accommodates',
#  'bedrooms',
#  'price',
#  'latitude',
#  'longitude']

# %%
# Duplicated entries if any
df_new.duplicated().sum()
# Out:
# 0

# %%
df_new.head()
# Out:
#      room_type             neighborhood  reviews  overall_satisfaction  \
# 0  Shared room  De Pijp / Rivierenbuurt        7                   4.5
# 1  Shared room             Centrum West       45                   4.5
# 2  Shared room          Watergraafsmeer        1                   0.0
# 3  Shared room             Centrum West        7                   5.0
# 4  Shared room   De Baarsjes / Oud West        1                   0.0
#
#    accommodates  bedrooms  price  \
# 0             2       1.0  156.0
# 1             4       1.0  126.0
# 2             3       1.0  132.0
# 3             4       1.0  121.0
# 4             2       1.0   93.0
#
#                                              name   latitude  longitude
# 0        Red Light/ Canal view apartment (Shared)  52.356209   4.887491
# 1  Sunny and Cozy Living room in quite neighbours  52.378518   4.896120
# 2                                       Amsterdam  52.338811   4.943592
# ...

# %%
df_new.overall_satisfaction.unique()
# Out:
# array([4.5, 0. , 5. , 4. , 1.5, 3.5, 2.5, 3. , 1. ])

# %%
df['satis_level'] = df_new['overall_satisfaction'].apply(lambda x: 'low' if x<2 else 'high' if x>3.99 else 'medium')
cats.append('satis_level')
print(f'categorical variables:  {cats}')
# Out:
# categorical variables:  ['room_type', 'neighborhood', 'name', 'satis_level']

# %%
df_new.reviews.unique()
# Out:
# array([  7,  45,   1, 184,  67,   2,   0,  26,  10,  15,   3,  11,   6,
#         73,  60,   9,   4,  12,  30,  19,  23,  17,  25,   8,  21,  13,
#         62,  16,  18,  80,  59,   5,  32,  28,  29,  57,  33, 278,  48,
#         37,  41, 195,  24,  22,  27,  91,  14,  71,  34,  36,  20,  35,
#         55, 124,  58,  87,  31,  44, 133, 136, 112,  95,  68, 103,  43,
#         69, 105,  56,  63,  49,  52, 111,  47,  50,  38,  61, 102,  46,
#        127, 108,  54,  76,  72,  66,  53, 167,  51, 190,  40, 284,  98,
#         99, 101,  42,  39,  75,  97, 106,  64,  82,  78,  86,  96,  65,
#         79,  77,  92, 100,  81,  85, 162,  88,  84, 447, 135, 144, 121,
#        122, 129, 116, 149, 120, 153,  70, 151, 232, 150, 110, 228, 114,
#        138, 113,  90, 119, 107, 125, 175, 104, 164,  83, 178, 140, 126,
#        410, 132, 165, 254, 115, 128, 354, 369, 117, 147, 109,  74, 209,
#        196,  89, 213,  94, 154, 159, 123, 146, 137, 177, 242, 130, 532,
# ...

# %%
df_cats = df[cats]
df_cats
# Out:
#           room_type             neighborhood  \
# 0       Shared room  De Pijp / Rivierenbuurt
# 1       Shared room             Centrum West
# 2       Shared room          Watergraafsmeer
# 3       Shared room             Centrum West
# 4       Shared room   De Baarsjes / Oud West
# ...             ...                      ...
# 18718  Private room          Bijlmer Centrum
# 18719  Private room          Bijlmer Centrum
# 18720  Private room  Geuzenveld / Slotermeer
# 18721  Private room             Centrum West
# 18722  Private room             Centrum West
#
#                                                  name satis_level
# 0            Red Light/ Canal view apartment (Shared)        high
# 1      Sunny and Cozy Living room in quite neighbours        high
# 2                                           Amsterdam         low
# 3                        Canal boat RIDE in Amsterdam        high
# 4        One room for rent in a three room appartment         low
# ...

# %%
df_nums = df[nums]
df_nums
# Out:
#        reviews  overall_satisfaction  accommodates  bedrooms  price  \
# 0            7                   4.5             2       1.0  156.0
# 1           45                   4.5             4       1.0  126.0
# 2            1                   0.0             3       1.0  132.0
# 3            7                   5.0             4       1.0  121.0
# 4            1                   0.0             2       1.0   93.0
# ...        ...                   ...           ...       ...    ...
# 18718       10                   5.0             3       1.0   32.0
# 18719        6                   5.0             4       1.0   24.0
# 18720        0                   0.0             1       1.0   38.0
# 18721       13                   4.5             2       1.0   36.0
# 18722      113                   4.5             2       1.0   35.0
#
#         latitude  longitude
# 0      52.356209   4.887491
# 1      52.378518   4.896120
# 2      52.338811   4.943592
# 3      52.376319   4.890028
# ...

# %%
fig = plt.figure(1, (14, 8))

for i,cat in enumerate(df_cats.drop(['name'], axis=1).columns):
    ax = plt.subplot(2,2,i+1)
    sns.countplot(df_cats[cat], order=df_cats[cat].value_counts().index)
    ax.set_xlabel(None)
    ax.set_title(f'Distribution of {cat}')
    plt.tight_layout()

plt.show()

# %%
df_cats.name.value_counts()
# Out:
# Amsterdam                                             36
# Lovely apartment near Vondelpark                      10
# Magnificent panoramic city view                        8
# Beautiful apartment in Amsterdam                       8
# Cosy apartment in Amsterdam                            8
#                                                       ..
# Bright and trendy apt, sunny balcony -De Pijp, RAI     1
# Bright & Cozy Apartment in the Pijp                    1
# NEW! Monumental Apartment In The Heart of the City     1
# A great apartment in Amsterdam’s vibrant ‘de Pijp’     1
# I have a room available for rent                       1
# Name: name, Length: 18150, dtype: int64

# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

geometry = [Point(xy) for xy in zip(df_new['longitude'], df_new['latitude'])]
gdf = GeoDataFrame(df_new, geometry=geometry)   

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15);

# %%
rows = len(nums)
cols = 3

fig = plt.figure(1, (18, rows*3))

i = 0
for col in nums:
    
    i += 1
    ax1 = plt.subplot(rows, cols,i)
    sns.histplot(x=col, data=df_nums)
    ax1.set_xlabel(None)
    ax1.set_title(f'{col} distribution')
    plt.tight_layout()

# %%
rows = len(nums)
cols = 3

fig = plt.figure(1, (18, rows*3))

i = 0
for col in nums:
    
    i += 1
    ax1 = plt.subplot(rows, cols,i)
    sns.distplot(df_nums[col])
    ax1.set_xlabel(None)
    ax1.set_title(f'{col} distribution')
    plt.tight_layout()

# %%
rows = len(nums)
cols = 3

fig = plt.figure(1, (18, rows*3))

i = 0
for col in nums:
    
    i += 1
    ax1 = plt.subplot(rows, cols,i)
    sns.boxplot(x=col, data=df_nums)
    ax1.set_xlabel(None)
    ax1.set_title(f'{col} distribution')
    plt.tight_layout()

# %% [markdown]
# **Outlier Analysis**

# %%
def tukey_outliers(x):
    q1 = np.percentile(x,25)
    q3 = np.percentile(x,75)
    
    iqr = q3-q1
    
    min_range = q1 - iqr*1.5
    max_range = q3 + iqr*1.5
    
    outliers = x[(x<min_range) | (x>max_range)]
    return outliers

# %%
for col in df_nums:
    outliers = tukey_outliers(df_nums[col])
    if len(outliers):
        print(f"* {col} has these tukey outliers,\n{outliers}\n")
    else:
        print(f"* {col} doesn't have any tukey outliers.\n")
# Out:
# * reviews has these tukey outliers,
# 1         45
# 5        184
# 6         67
# 20        73
# 22        60
#         ...
# 18707    160
# 18712     62
# 18713    118
# 18716    281
# 18722    113
# Name: reviews, Length: 1839, dtype: int64
#
# * overall_satisfaction doesn't have any tukey outliers.
#
# * accommodates has these tukey outliers,
# 6        16
# 9        12
# 29       16
# 33        8
# 34        8
#          ..
# 16606    10
# 17037     8
# 18288     8
# 18425     8
# 18711     8
# Name: accommodates, Length: 169, dtype: int64
#
# * bedrooms has these tukey outliers,
# 33       4.0
# 37       4.0
# 39       4.0
# 42       4.0
# 47       4.0
#         ...
# 13668    4.0
# 13717    4.0
# 13776    7.0
# 14130    4.0
# 14666    4.0
# Name: bedrooms, Length: 568, dtype: float64
#
# * price has these tukey outliers,
# 6        462.0
# 7        414.0
# 33       763.0
# 34       445.0
# 35       721.0
#          ...
# 14842    359.0
# 14843    324.0
# 14844    420.0
# ...
